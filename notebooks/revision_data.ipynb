# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("data/raw/wingspan-20260128.xlsx")
df
# Out:
#                 Common name          Scientific name       Set   Color  \
# 0                       NaN                      NaN       NaN     NaN
# 1                       NaN                      NaN       NaN     NaN
# 2            Abbott's Booby         Papasula abbotti   oceania   white
# 3        Acadian Flycatcher      Empidonax virescens   promoUS   brown
# 4          Acorn Woodpecker  Melanerpes formicivorus      core   brown
# ..                      ...                      ...       ...     ...
# 704  Yellow-Headed Caracara      Daptrius chimachima  americas    pink
# 705   Yellow-Rumped Warbler       Setophaga coronata      core   brown
# 706            Yellowhammer      Emberiza citrinella  european    teal
# 707              Yellowhead      Mohoua ochrocephala   promoNZ  yellow
# 708              Zebra Dove         Geopelia striata      asia   brown
#
#                                             Power text Predator Flocking  \
# ...

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#           Common name          Scientific name      Set  Color  \
# 0                 NaN                      NaN      NaN    NaN
# 1                 NaN                      NaN      NaN    NaN
# 2      Abbott's Booby         Papasula abbotti  oceania  white
# 3  Acadian Flycatcher      Empidonax virescens  promoUS  brown
# 4    Acorn Woodpecker  Melanerpes formicivorus     core  brown
#
#                                           Power text Predator Flocking  \
# 0                                                NaN      NaN      NaN
# 1                                                NaN      NaN      NaN
# 2  Draw 3 bonus cards, then discard 2. You may di...      NaN      NaN
# 3  Draw and discard 1 [card] from the deck. If it...      NaN      NaN
# 4  Gain 1 [seed] from the birdfeeder, if availabl...      NaN      NaN
#
#   Bonus card  Victory points Nest type  Egg limit Wingspan Forest Grassland  \
# 0        NaN             NaN       NaN        NaN      NaN    NaN       NaN
# ...

# %%
df.head(15).to_csv("data/raw/wingspan_head15.csv", index=False)
